# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ranks_iits.csv")
df1 = pd.read_csv("ranks_iiits.csv")
df2 = pd.read_csv("ranks_nits.csv")
df3 = pd.read_csv("ranks_gftis.csv")

# %%
df
# Out:
#                                        Institute  \
# 0     Indian Institute of Technology Bhubaneswar
# 1     Indian Institute of Technology Bhubaneswar
# 2     Indian Institute of Technology Bhubaneswar
# 3     Indian Institute of Technology Bhubaneswar
# 4     Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 2798      Indian Institute of Technology Dharwad
# 2799      Indian Institute of Technology Dharwad
# 2800      Indian Institute of Technology Dharwad
# 2801      Indian Institute of Technology Dharwad
# 2802      Indian Institute of Technology Dharwad
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df = df.convert_dtypes()
df.dropna(inplace=True)
df = df[df["Closing Rank"].apply(lambda x: x.isnumeric())]
df = df[df["Opening Rank"].apply(lambda x: x.isnumeric())]
df['Closing Rank'] = df['Closing Rank'].astype(int)
df['Opening Rank']  = df['Opening Rank'].astype(int)

# %%
df
# Out:
#                                        Institute  \
# 0     Indian Institute of Technology Bhubaneswar
# 1     Indian Institute of Technology Bhubaneswar
# 2     Indian Institute of Technology Bhubaneswar
# 3     Indian Institute of Technology Bhubaneswar
# 4     Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 2798      Indian Institute of Technology Dharwad
# 2799      Indian Institute of Technology Dharwad
# 2800      Indian Institute of Technology Dharwad
# 2801      Indian Institute of Technology Dharwad
# 2802      Indian Institute of Technology Dharwad
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df.dtypes
# Out:
# Institute                string
# Academic Program Name    string
# Quota                    string
# Seat Type                string
# Gender                   string
# Opening Rank              int32
# Closing Rank              int32
# dtype: object

# %%
df1
# Out:
#                                              Institute  \
# 0    Atal Bihari Vajpayee Indian Institute of Infor...
# 1    Atal Bihari Vajpayee Indian Institute of Infor...
# 2    Atal Bihari Vajpayee Indian Institute of Infor...
# 3    Atal Bihari Vajpayee Indian Institute of Infor...
# 4    Atal Bihari Vajpayee Indian Institute of Infor...
# ..                                                 ...
# 732  Indian Institute of Information Technology, Va...
# 733  Indian Institute of Information Technology, Va...
# 734  Indian Institute of Information Technology, Va...
# 735  Indian Institute of Information Technology, Va...
# 736  Indian Institute of Information Technology, Va...
#
#                                  Academic Program Name Quota   Seat Type  \
# 0    Computer Science and Engineering (4 Years, Bac...    AI        OPEN
# 1    Computer Science and Engineering (4 Years, Bac...    AI        OPEN
# 2    Computer Science and Engineering (4 Years, Bac...    AI  OPEN (PwD)
# ...

# %%
df1 = df1.convert_dtypes()
df1.dropna(inplace=True)
 #df1 = df1[df1["Closing Rank"].apply(lambda x: x.isnumeric())]
# df1 = df1[df1["Opening Rank"].apply(lambda x: x.isnumeric())]
# df1['Closing Rank'] = df1['Closing Rank'].astype(int)
# df1['Opening Rank']  = df1['Opening Rank'].astype(int)

# %%
df1.dtypes
# Out:
# Institute                string
# Academic Program Name    string
# Quota                    string
# Seat Type                string
# Gender                   string
# Opening Rank              Int64
# Closing Rank              Int64
# dtype: object

# %%
df1
# Out:
#                                              Institute  \
# 0    Atal Bihari Vajpayee Indian Institute of Infor...
# 1    Atal Bihari Vajpayee Indian Institute of Infor...
# 2    Atal Bihari Vajpayee Indian Institute of Infor...
# 3    Atal Bihari Vajpayee Indian Institute of Infor...
# 4    Atal Bihari Vajpayee Indian Institute of Infor...
# ..                                                 ...
# 732  Indian Institute of Information Technology, Va...
# 733  Indian Institute of Information Technology, Va...
# 734  Indian Institute of Information Technology, Va...
# 735  Indian Institute of Information Technology, Va...
# 736  Indian Institute of Information Technology, Va...
#
#                                  Academic Program Name Quota   Seat Type  \
# 0    Computer Science and Engineering (4 Years, Bac...    AI        OPEN
# 1    Computer Science and Engineering (4 Years, Bac...    AI        OPEN
# 2    Computer Science and Engineering (4 Years, Bac...    AI  OPEN (PwD)
# ...

# %%
df2
# Out:
#                                               Institute  \
# 0     Dr. B R Ambedkar National Institute of Technol...
# 1     Dr. B R Ambedkar National Institute of Technol...
# 2     Dr. B R Ambedkar National Institute of Technol...
# 3     Dr. B R Ambedkar National Institute of Technol...
# 4     Dr. B R Ambedkar National Institute of Technol...
# ...                                                 ...
# 5391  Indian Institute of Engineering Science and Te...
# 5392  Indian Institute of Engineering Science and Te...
# 5393  Indian Institute of Engineering Science and Te...
# 5394  Indian Institute of Engineering Science and Te...
# 5395  Indian Institute of Engineering Science and Te...
#
#                                   Academic Program Name Quota Seat Type  \
# 0      Bio Technology (4 Years, Bachelor of Technology)    HS      OPEN
# 1      Bio Technology (4 Years, Bachelor of Technology)    HS      OPEN
# 2      Bio Technology (4 Years, Bachelor of Technology)    HS       EWS
# ...

# %%
df2 = df2.convert_dtypes()
df2.dropna(inplace=True)
# df2 = df2[df2["Closing Rank"].apply(lambda x: x.isnumeric())]
# df2 = df2[df2["Opening Rank"].apply(lambda x: x.isnumeric())]
# df2['Closing Rank'] = df2['Closing Rank'].astype(int)
# df2['Opening Rank']  = df2['Opening Rank'].astype(int)

# %%
df2.dtypes
# Out:
# Institute                string
# Academic Program Name    string
# Quota                    string
# Seat Type                string
# Gender                   string
# Opening Rank              Int64
# Closing Rank              Int64
# dtype: object

# %%
df2
# Out:
#                                               Institute  \
# 0     Dr. B R Ambedkar National Institute of Technol...
# 1     Dr. B R Ambedkar National Institute of Technol...
# 2     Dr. B R Ambedkar National Institute of Technol...
# 3     Dr. B R Ambedkar National Institute of Technol...
# 4     Dr. B R Ambedkar National Institute of Technol...
# ...                                                 ...
# 5391  Indian Institute of Engineering Science and Te...
# 5392  Indian Institute of Engineering Science and Te...
# 5393  Indian Institute of Engineering Science and Te...
# 5394  Indian Institute of Engineering Science and Te...
# 5395  Indian Institute of Engineering Science and Te...
#
#                                   Academic Program Name Quota Seat Type  \
# 0      Bio Technology (4 Years, Bachelor of Technology)    HS      OPEN
# 1      Bio Technology (4 Years, Bachelor of Technology)    HS      OPEN
# 2      Bio Technology (4 Years, Bachelor of Technology)    HS       EWS
# ...

# %%
df3
# Out:
#                        Institute  \
# 0      Assam University, Silchar
# 1      Assam University, Silchar
# 2      Assam University, Silchar
# 3      Assam University, Silchar
# 4      Assam University, Silchar
# ..                           ...
# 791  Central University of Jammu
# 792  Central University of Jammu
# 793  Central University of Jammu
# 794  Central University of Jammu
# 795  Central University of Jammu
#
#                                  Academic Program Name Quota Seat Type  \
# 0    Agricultural Engineering (4 Years, Bachelor of...    AI      OPEN
# 1    Agricultural Engineering (4 Years, Bachelor of...    AI      OPEN
# 2    Agricultural Engineering (4 Years, Bachelor of...    AI       EWS
# 3    Agricultural Engineering (4 Years, Bachelor of...    AI   OBC-NCL
# 4    Agricultural Engineering (4 Years, Bachelor of...    AI   OBC-NCL
# ..                                                 ...   ...       ...
# ...

# %%
df3 = df3.convert_dtypes()
df3.dropna(inplace=True)
# df3 = df3[df3["Closing Rank"].apply(lambda x: x.isnumeric())]
# df3 = df3[df3["Opening Rank"].apply(lambda x: x.isnumeric())]
# df3['Closing Rank'] = df3['Closing Rank'].astype(int)
# df3['Opening Rank']  = df3['Opening Rank'].astype(int)

# %%
df3.dtypes
# Out:
# Institute                string
# Academic Program Name    string
# Quota                    string
# Seat Type                string
# Gender                   string
# Opening Rank              Int64
# Closing Rank              Int64
# dtype: object

# %%
df3
# Out:
#                        Institute  \
# 0      Assam University, Silchar
# 1      Assam University, Silchar
# 2      Assam University, Silchar
# 3      Assam University, Silchar
# 4      Assam University, Silchar
# ..                           ...
# 791  Central University of Jammu
# 792  Central University of Jammu
# 793  Central University of Jammu
# 794  Central University of Jammu
# 795  Central University of Jammu
#
#                                  Academic Program Name Quota Seat Type  \
# 0    Agricultural Engineering (4 Years, Bachelor of...    AI      OPEN
# 1    Agricultural Engineering (4 Years, Bachelor of...    AI      OPEN
# 2    Agricultural Engineering (4 Years, Bachelor of...    AI       EWS
# 3    Agricultural Engineering (4 Years, Bachelor of...    AI   OBC-NCL
# 4    Agricultural Engineering (4 Years, Bachelor of...    AI   OBC-NCL
# ..                                                 ...   ...       ...
# ...

# %%
dfMains = pd.concat([df1,df2,df3])

# %%
dfMains
# Out:
#                                              Institute  \
# 0    Atal Bihari Vajpayee Indian Institute of Infor...
# 1    Atal Bihari Vajpayee Indian Institute of Infor...
# 2    Atal Bihari Vajpayee Indian Institute of Infor...
# 3    Atal Bihari Vajpayee Indian Institute of Infor...
# 4    Atal Bihari Vajpayee Indian Institute of Infor...
# ..                                                 ...
# 791                        Central University of Jammu
# 792                        Central University of Jammu
# 793                        Central University of Jammu
# 794                        Central University of Jammu
# 795                        Central University of Jammu
#
#                                  Academic Program Name Quota   Seat Type  \
# 0    Computer Science and Engineering (4 Years, Bac...    AI        OPEN
# 1    Computer Science and Engineering (4 Years, Bac...    AI        OPEN
# 2    Computer Science and Engineering (4 Years, Bac...    AI  OPEN (PwD)
# ...

# %%
dfMains.to_csv('Mains.csv',index=False)

# %%
df
# Out:
#                                        Institute  \
# 0     Indian Institute of Technology Bhubaneswar
# 1     Indian Institute of Technology Bhubaneswar
# 2     Indian Institute of Technology Bhubaneswar
# 3     Indian Institute of Technology Bhubaneswar
# 4     Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 2798      Indian Institute of Technology Dharwad
# 2799      Indian Institute of Technology Dharwad
# 2800      Indian Institute of Technology Dharwad
# 2801      Indian Institute of Technology Dharwad
# 2802      Indian Institute of Technology Dharwad
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df.to_csv("Adv.csv",index = False)
