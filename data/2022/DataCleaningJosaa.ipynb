# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                                        Institute  \
# 0     Indian Institute of Technology Bhubaneswar
# 1     Indian Institute of Technology Bhubaneswar
# 2     Indian Institute of Technology Bhubaneswar
# 3     Indian Institute of Technology Bhubaneswar
# 4     Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 9727                 Central University of Jammu
# 9728                 Central University of Jammu
# 9729                 Central University of Jammu
# 9730                 Central University of Jammu
# 9731                 Central University of Jammu
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df.dtypes
# Out:
# Institute                object
# Academic Program Name    object
# Quota                    object
# Seat Type                object
# Gender                   object
# Opening Rank             object
# Closing Rank             object
# dtype: object

# %%
df = df.convert_dtypes()
df
# Out:
#                                        Institute  \
# 0     Indian Institute of Technology Bhubaneswar
# 1     Indian Institute of Technology Bhubaneswar
# 2     Indian Institute of Technology Bhubaneswar
# 3     Indian Institute of Technology Bhubaneswar
# 4     Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 9727                 Central University of Jammu
# 9728                 Central University of Jammu
# 9729                 Central University of Jammu
# 9730                 Central University of Jammu
# 9731                 Central University of Jammu
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df.dtypes
# Out:
# Institute                string
# Academic Program Name    string
# Quota                    string
# Seat Type                string
# Gender                   string
# Opening Rank             string
# Closing Rank             string
# dtype: object

# %%
df.dropna(inplace=True)

# %%
df = df[df["Closing Rank"].apply(lambda x: x.isnumeric())]

# %%
df
# Out:
#                                        Institute  \
# 0     Indian Institute of Technology Bhubaneswar
# 1     Indian Institute of Technology Bhubaneswar
# 2     Indian Institute of Technology Bhubaneswar
# 3     Indian Institute of Technology Bhubaneswar
# 4     Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 9727                 Central University of Jammu
# 9728                 Central University of Jammu
# 9729                 Central University of Jammu
# 9730                 Central University of Jammu
# 9731                 Central University of Jammu
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df = df[df["Opening Rank"].apply(lambda x: x.isnumeric())]

# %%
df['Closing Rank'] = df['Closing Rank'].astype(int)

# %%
 df['Opening Rank']  = df['Opening Rank'].astype(int)

# %%
df.dropna()
# Out:
#                                        Institute  \
# 0     Indian Institute of Technology Bhubaneswar
# 1     Indian Institute of Technology Bhubaneswar
# 2     Indian Institute of Technology Bhubaneswar
# 3     Indian Institute of Technology Bhubaneswar
# 4     Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 9727                 Central University of Jammu
# 9728                 Central University of Jammu
# 9729                 Central University of Jammu
# 9730                 Central University of Jammu
# 9731                 Central University of Jammu
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df.dtypes
# Out:
# Institute                string
# Academic Program Name    string
# Quota                    string
# Seat Type                string
# Gender                   string
# Opening Rank              int32
# Closing Rank              int32
# dtype: object

# %%
df.sort_values(by = 'Closing Rank')
# Out:
#                                          Institute  \
# 200          Indian Institute of Technology Bombay
# 9358  School of Planning & Architecture, New Delhi
# 203          Indian Institute of Technology Bombay
# 196          Indian Institute of Technology Bombay
# 193          Indian Institute of Technology Bombay
# ...                                            ...
# 5675       National Institute of Technology Sikkim
# 6192     National Institute of Technology, Mizoram
# 6205     National Institute of Technology, Mizoram
# 6204     National Institute of Technology, Mizoram
# 6181     National Institute of Technology, Mizoram
#
#                                   Academic Program Name Quota      Seat Type  \
# 200   Computer Science and Engineering (4 Years, Bac...    AI       SC (PwD)
# 9358   Architecture (5 Years, Bachelor of Architecture)    AI       ST (PwD)
# 203   Computer Science and Engineering (4 Years, Bac...    AI       ST (PwD)
# ...

# %%
result = df.loc[(df['Institute'] == 'Indian Institute of Technology Bombay') & (df['Seat Type'] == "OPEN") & (df['Closing Rank'] > 1000)]

# %%
result.sort_values(by = 'Closing Rank')
# Out:
#                                  Institute  \
# 216  Indian Institute of Technology Bombay
# 275  Indian Institute of Technology Bombay
# 252  Indian Institute of Technology Bombay
# 288  Indian Institute of Technology Bombay
# 229  Indian Institute of Technology Bombay
# 153  Indian Institute of Technology Bombay
# 204  Indian Institute of Technology Bombay
# 132  Indian Institute of Technology Bombay
# 145  Indian Institute of Technology Bombay
# 241  Indian Institute of Technology Bombay
# 276  Indian Institute of Technology Bombay
# 253  Indian Institute of Technology Bombay
# 175  Indian Institute of Technology Bombay
# 297  Indian Institute of Technology Bombay
# 146  Indian Institute of Technology Bombay
# 133  Indian Institute of Technology Bombay
# 289  Indian Institute of Technology Bombay
# 205  Indian Institute of Technology Bombay
# 154  Indian Institute of Technology Bombay
# 264  Indian Institute of Technology Bombay
# 242  Indian Institute of Technology Bombay
# ...

# %%
df
# Out:
#                                        Institute  \
# 0     Indian Institute of Technology Bhubaneswar
# 1     Indian Institute of Technology Bhubaneswar
# 2     Indian Institute of Technology Bhubaneswar
# 3     Indian Institute of Technology Bhubaneswar
# 4     Indian Institute of Technology Bhubaneswar
# ...                                          ...
# 9727                 Central University of Jammu
# 9728                 Central University of Jammu
# 9729                 Central University of Jammu
# 9730                 Central University of Jammu
# 9731                 Central University of Jammu
#
#                                   Academic Program Name Quota Seat Type  \
# 0     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 1     Civil Engineering (4 Years, Bachelor of Techno...    AI      OPEN
# 2     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# 3     Civil Engineering (4 Years, Bachelor of Techno...    AI       EWS
# ...

# %%
df.dtypes
# Out:
# Institute                string
# Academic Program Name    string
# Quota                    string
# Seat Type                string
# Gender                   string
# Opening Rank              int32
# Closing Rank              int32
# dtype: object

# %%
df.to_csv("DataFinal.csv",index=True)
